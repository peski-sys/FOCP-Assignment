# %%
def letters_in_either(word1, word2): # Letters that appear in at least one of the two words
    return sorted(set(word1) | set(word2)) 

def letters_in_both(word1, word2): # Letters that appear in both words
    return sorted(set(word1) & set(word2))

def letters_in_one_only(word1, word2): # Letters that appear in either word, but not in both
    return sorted(set(word1) ^ set(word2))

print(letters_in_either("saugat", "gat"))
print(letters_in_both("saugat", "gat"))
print(letters_in_one_only("saugat", "gat"))
# Out:
# ['a', 'g', 's', 't', 'u']
# ['a', 'g', 't']
# ['s', 'u']
