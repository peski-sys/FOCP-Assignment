# %%
password = input("Enter your Password: ")
recheckPassword = input("Re Enter your Password: ")


if(len(password) >= 8 and len(password) <= 12):
    if(password == recheckPassword):
        print("Password Set")
    else:
        print("Error, Please try again later.")
else:
    print("Password Should be 8 to 12 characters long (inclusive), Check that first")
# Out:
# Password Should be 8 to 12 characters long (inclusive), Check that first
