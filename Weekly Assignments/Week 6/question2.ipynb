# %%
def Factor(n):#checks the factors of the number
    result = []
    for i in range(1, n + 1):
        if n % i == 0:
            result.append(i)
    return result


print(Factor(100))
# Out:
# [1, 2, 4, 5, 10, 20, 25, 50, 100]
