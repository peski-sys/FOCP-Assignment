# %%
import sys

args = sys.argv[1:]

if not args:
    print("Error: No arguments provided")
    sys.exit()

args.sort(key=len)
print("Shortest argument:", args[0])
# Out:
# Shortest argument: --f=c:\Users\LEGION\AppData\Roaming\jupyter\runtime\kernel-v3bddb6265f4c84ae09bcd1fba88717178966cbf5b.json
