# %%
tempInCelsius = float(input("Enter a Temperature in in Celsius: "))
inFahrenheit = (tempInCelsius * 1.8) + 32
print(f"{tempInCelsius}C is equivalent to {inFahrenheit}F.")
# Out:
# 32.5C is equivalent to 90.5F.
