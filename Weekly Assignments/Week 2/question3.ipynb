# %%
numberOfStudents = int(input("How Many Students?: "))
numberOfGroups = int(input("Required Group Size?: "))

totalGroups = int(numberOfStudents / numberOfGroups)
leftOverStudents = numberOfStudents % numberOfGroups

print(f"There will be {totalGroups} groups with {leftOverStudents} students left over.")
# Out:
# There will be 5 groups with 3 students left over.
